# %% [markdown]
# # RAG

# %% [markdown]
# ## Requirements

# %%
# %%capture
# !pip install transformers accelerate bitsandbytes langchain langchain-community langchain-huggingface sentence-transformers faiss-gpu pandas gdown

# %% [markdown]
# ## Dataset

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI/view?usp=sharing
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI
# From (redirected): https://drive.google.com/uc?id=1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI&confirm=t&uuid=a5ed664f-080a-4da5-8471-de9882e7ff09
# To: /content/IMDB_crawled.json
# 100% 292M/292M [00:03<00:00, 83.9MB/s]

# %% [markdown]
# ## Config

# %%
class Config:
    EMBEDDING_MODEL_NAME="thenlper/gte-base"
    LLM_MODEL_NAME="HuggingFaceH4/zephyr-7b-beta"
    K = 5 # top K retrieval

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd

try:
    df = pd.read_json('IMDB_crawled.json')
except FileNotFoundError:
    df = pd.read_json('../../../crawled_data/IMDB_crawled_01.json')

# %%
df.head()
# Out:
#           id                                              title  \
# 0  tt0071562                              The Godfather Part II
# 1  tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 2  tt0110912                                       Pulp Fiction
# 3  tt0068646                                      The Godfather
# 4  tt0111161                           The Shawshank Redemption
#
#                                   first_page_summary release_year   mpaa  \
# 0  The early life and career of Vito Corleone in ...         1974      R
# 1  A meek Hobbit from the Shire and eight compani...         2001  PG-13
# 2  The lives of two mob hitmen, a boxer, a gangst...         1994      R
# 3  The aging patriarch of an organized crime dyna...         1972      R
# 4  Over the course of several years, two convicts...         1994      R
#
#                     budget gross_worldwide  rating               directors  \
# 0  $13,000,000 (estimated)     $47,962,683     9.0  [Francis Ford Coppola]
# 1  $93,000,000 (estimated)    $884,041,698     8.9         [Peter Jackson]
# 2   $8,000,000 (estimated)    $213,928,762     8.9     [Quentin Tarantino]
# 3   $6,000,000 (estimated)    $250,342,030     9.2  [Francis Ford Coppola]
# 4  $25,000,000 (estimated)     $28,904,232     9.3        [Frank Darabont]
#
#                           writers  \
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4  [Stephen King, Frank Darabont]
#
#                                              stars  \
# 0       [Al Pacino, Robert De Niro, Robert Duvall]
# 1       [Elijah Wood, Ian McKellen, Orlando Bloom]
# 2  [John Travolta, Uma Thurman, Samuel L. Jackson]
# 3           [Marlon Brando, Al Pacino, James Caan]
# 4        [Tim Robbins, Morgan Freeman, Bob Gunton]
#
#                                        related_links  \
# 0  [https://imdb.com/title/tt0068646/?ref_=tt_sim...
# 1  [https://imdb.com/title/tt0167261/?ref_=tt_sim...
# 2  [https://imdb.com/title/tt0137523/?ref_=tt_sim...
# 3  [https://imdb.com/title/tt0071562/?ref_=tt_sim...
# 4  [https://imdb.com/title/tt0468569/?ref_=tt_sim...
#
#                                       languages           countries_of_origin  \
# 0  [English, Italian, Spanish, Latin, Sicilian]               [United States]
# 1                           [English, Sindarin]  [New Zealand, United States]
# 2                    [English, Spanish, French]               [United States]
# 3                     [English, Italian, Latin]               [United States]
# 4                                     [English]               [United States]
#
#                                            summaries  \
# 0  [The early life and career of Vito Corleone in...
# 1  [A meek Hobbit from the Shire and eight compan...
# 2  [The lives of two mob hitmen, a boxer, a gangs...
# 3  [The aging patriarch of an organized crime dyn...
# 4  [Over the course of several years, two convict...
#
#                                             synposis  \
# 0  [The Godfather Part II presents two parallel s...
# 1  [Galadriel (Cate Blanchett) (The Elven co-rule...
# 2  [Narrative structure\nPulp Fiction's narrative...
# 3  [In late summer 1945, guests are gathered for ...
# 4  [In 1947, Andy Dufresne (Tim Robbins), a banke...
#
#                                              reviews  \
# 0  [[Coppola's masterpiece is rivaled only by "Th...
# 1  [[Here is one film that lived up to its hype, ...
# 2  [[I like the bit with the cheeseburger. It mak...
# 3  [['The Godfather' is the pinnacle of flawless ...
# 4  [[The Shawshank Redemption is written and dire...
#
#                        genres
# 0              [Crime, Drama]
# 1  [Action, Adventure, Drama]
# 2              [Crime, Drama]
# 3              [Crime, Drama]
# 4                     [Drama]

# %%
import os

os.makedirs('data', exist_ok=True)

# preprocess your data and only store the needed data as the context window for embedding model is limited

df = df[['id', 'title', 'first_page_summary', 'release_year', 'mpaa', 'genres', 'rating', 'directors', 'stars', 'languages']]

df.to_csv('data/imdb.csv', index=False)

# %% [markdown]
# ## Vectorizer

# %% [markdown]
# load the CSV file and vectorize the rows using HuggingFaceEmbeddings.
# Store the results using FAISS vectorstore.
# Save the vectorestore in a pickle file for future usages.

# %%
import pickle

from langchain.document_loaders.csv_loader import CSVLoader
from langchain.vectorstores.utils import DistanceStrategy
from langchain.vectorstores.faiss import FAISS

from langchain_community.embeddings import HuggingFaceEmbeddings

# load the csv
loader = CSVLoader(file_path='data/imdb.csv')
documents = loader.load()

# load the embeddings model
embeddings = HuggingFaceEmbeddings(model_name=Config.EMBEDDING_MODEL_NAME)

# save embed the documents using the model in a vectorstore
vectorstore = FAISS.from_documents(documents, embeddings, distance_strategy=DistanceStrategy.COSINE)

# with open("data/vectorstore.pkl", "wb") as f:
#     pickle.dump(vectorstore, f)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/68.1k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/618 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/219M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# load the vectorstore as a retriever.

# %%
# with open("data/vectorstore.pkl", "rb") as f:
#     vectorstore = pickle.load(f)

# load the retriever from the vectorstore
retriever = vectorstore.as_retriever(search_kwargs={"k": Config.K})

# %% [markdown]
# ## LLM

# %% [markdown]
# load the quantized LLM.

# %%
import torch

from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import pipeline

from langchain_community.llms.huggingface_pipeline import HuggingFacePipeline

# load the quantization config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(Config.LLM_MODEL_NAME, quantization_config=bnb_config, device_map="cuda:0")
tokenizer = AutoTokenizer.from_pretrained(Config.LLM_MODEL_NAME)

# init the pipeline
READER_LLM = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    temperature=0.7,
    top_p=0.95,
    repetition_penalty=1.15,
    do_sample=True,
)

llm = HuggingFacePipeline(
    pipeline=READER_LLM,
)
# Out:
# config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/8 [00:00<?, ?it/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/816M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFacePipeline`.
#   warn_deprecated(

# %% [markdown]
# initialize the prompt template for the query chain. query chain is used to get a query from the chat history. you may change the prompt as you like to get better results.

# %%
from langchain.prompts import PromptTemplate

from langchain_core.output_parsers import StrOutputParser

class LoggerStrOutputParser(StrOutputParser):
    def parse(self, text: str) -> str:
        # process the LLM output
        print(f"QUERY: {text}\n\n")
        return super().parse(text)

query_transform_prompt = PromptTemplate(
    input_variables=["messages"],
    template="""<|system|>You are a movie database assistant. Your job is to extract the core search terms from the conversation for finding optimal movie recommendations.
{messages}
<|user|>
Give me the search keywords derived from the conversation above.
<|assistant|>"""
)

# init the query chain
query_transforming_retriever_chain = (
    query_transform_prompt
    | llm
    | LoggerStrOutputParser()
    | retriever
)

# %% [markdown]
# initialize the main retrieval chain that gives the resulting documents to LLM and gets the output back.

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

from langchain_core.runnables import RunnablePassthrough

prompt = PromptTemplate(
    input_variables=["context", "messages"],
    template="""<|system|>You are a movie recommendation assistant. Your task is to recommend the best movie from the provided list based on the user's preferences and query. Ensure to select the movie that closely matches the user's request.
The user is asking for a movie recommendation, and you have a list of movies to choose from.
Based on the user's query and the given movie list, provide a detailed recommendation including the movie's title, release year, genres, rating, directors, stars, and a brief summary.

Movie list:
---------------------------
{context}
---------------------------

{messages}
<|assistant|>"""
)

# init the retriver chain
retrieval_chain = create_stuff_documents_chain(llm, prompt)

# %% [markdown]
# write the conversation helper class for easier testing.

# %%
class Conversation:
    def __init__(self):
        self.messages = []

    def add_assistant_message(self, message):
        self.messages.append(('assistant', message))

    def add_user_message(self, message):
        self.messages.append(('user', message))

    def get_messages(self):
        # concatenate the messages with the roles in the instruction format
        return "\n".join([f"<|{role}|>{message}" for role, message in self.messages])

    def chat(self, message):
        self.add_user_message(message)
        messages = self.get_messages()
        # invoke the chain
        response = retrieval_chain.invoke({
            "context": query_transforming_retriever_chain.invoke(messages),
            "messages": messages
        })
        self.add_assistant_message(response)
        return response

# %% [markdown]
# ## Test

# %% [markdown]
# talk with the RAG to see how good it performs.

# %%
c = Conversation()
A = c.chat('give me a science fiction movie similar to the movie Predestination(2014)')
print(A)
# Out:
# QUERY: <|system|>You are a movie database assistant. Your job is to extract the core search terms from the conversation for finding optimal movie recommendations.
# <|user|>give me a science fiction movie similar to the movie Predestination(2014)
# <|user|>
# Give me the search keywords derived from the conversation above.
# <|assistant|>
# Science fiction movie similar to Predestination (2014)
# Keywords: Science fiction, time travel, thriller, twist ending, Ethan Hawke, Emma Roberts, Robert Carnellay, Max Landis (writer), Michael Spierce (director).
#
#
# <|system|>You are a movie recommendation assistant. Your task is to recommend the best movie from the provided list based on the user's preferences and query. Ensure to select the movie that closely matches the user's request.
# The user is asking for a movie recommendation, and you have a list of movies to choose from.
# Based on the user's query and the given movie list, provide a detailed recommendation including the movie's title, release year, genres, rating, directors, stars, and a brief summary.
#
# Movie list:
# ---------------------------
# id: tt1877832
# title: X-Men: Days of Future Past
# first_page_summary: The X-Men send Wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.
# release_year: 2014
# mpaa: PG-13
# genres: ['Action', 'Adventure', 'Sci-Fi']
# rating: 7.9
# directors: ['Bryan Singer']
# stars: ['Patrick Stewart', 'Ian McKellen', 'Hugh Jackman']
# languages: ['English', 'Vietnamese', 'French']
#
# id: tt1631867
# title: Edge of Tomorrow
# first_page_summary: A soldier fighting aliens gets to relive the same day over and over again, the day restarting every time he dies.
# release_year: 2014
# mpaa: PG-13
# genres: ['Action', 'Adventure', 'Sci-Fi']
# rating: 7.9
# directors: ['Doug Liman']
# stars: ['Tom Cruise', 'Emily Blunt', 'Bill Paxton']
# languages: ['English']
#
# id: tt14730032
# title: Phenomenon Blade Runner
# first_page_summary: In 1982 a film came to the cinema that is set in the near future of Los Angeles in 2019 and itself changed the future of cinema as it is one of the most influential science fiction films eve... Read all
# release_year: 2021
# mpaa:
# genres: ['Documentary']
# rating: 6.7
# directors: ['Boris Hars-Tschachotin']
# stars: ['Joanna Cassidy', 'Harrison Ford', 'Ryan Gosling']
# languages: ['German', 'English']
#
# id: tt5181838
# title: Back to the Future?
# first_page_summary: Marty and Doc Brown go back to 2015 and find that one detail has changed the future as they knew it.
# release_year: 2015
# mpaa:
# genres: ['Short', 'Sci-Fi']
# rating: 8.1
# directors: ['Kyle Chen']
# stars: ['Jeffrey Weissman', 'Logan Wildey', 'Michael Garcia']
# languages:
#
# id: tt0118884
# title: Contact
# first_page_summary: Dr. Ellie Arroway, after years of searching, finds conclusive radio proof of extraterrestrial intelligence, sending plans for a mysterious machine.
# release_year: 1997
# mpaa: PG
# genres: ['Drama', 'Mystery', 'Sci-Fi']
# rating: 7.5
# directors: ['Robert Zemeckis']
# stars: ['Jodie Foster', 'Matthew McConaughey', 'Tom Skerritt']
# languages: ['English', 'Spanish', 'German', 'Russian']
# ---------------------------
#
# <|user|>give me a science fiction movie similar to the movie Predestination(2014)
# <|assistant|>Sure! Based on your preference for science fiction movies like Predestination (2014), I would recommend the movie "Edge of Tomorrow" (2014). Both films share elements of sci-fi action and time travel themes. In Edge of Tomorrow, Tom Cruise plays the role of Major William Cage, who gets stuck in a time loop during a war against an alien race. As Cage tries to break free from this cycle, he realizes that the only way to win the war is by learning from his mistakes and working alongside the skilled Rita Vrataski (played by Emily Blunt). This film combines thrilling action sequences with thought-provoking ideas about fate and destiny, making it a must-watch for fans of Predestination.

# %%
A = c.chat('give one that is directed by christopher nolan')
print(A)
# Out:
# QUERY: <|system|>You are a movie database assistant. Your job is to extract the core search terms from the conversation for finding optimal movie recommendations.
# <|user|>give me a science fiction movie similar to the movie Predestination(2014)
# <|assistant|><|system|>You are a movie recommendation assistant. Your task is to recommend the best movie from the provided list based on the user's preferences and query. Ensure to select the movie that closely matches the user's request.
# The user is asking for a movie recommendation, and you have a list of movies to choose from.
# Based on the user's query and the given movie list, provide a detailed recommendation including the movie's title, release year, genres, rating, directors, stars, and a brief summary.
#
# Movie list:
# ---------------------------
# id: tt1877832
# title: X-Men: Days of Future Past
# first_page_summary: The X-Men send Wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.
# release_year: 2014
# mpaa: PG-13
# genres: ['Action', 'Adventure', 'Sci-Fi']
# rating: 7.9
# directors: ['Bryan Singer']
# stars: ['Patrick Stewart', 'Ian McKellen', 'Hugh Jackman']
# languages: ['English', 'Vietnamese', 'French']
#
# id: tt1631867
# title: Edge of Tomorrow
# first_page_summary: A soldier fighting aliens gets to relive the same day over and over again, the day restarting every time he dies.
# release_year: 2014
# mpaa: PG-13
# genres: ['Action', 'Adventure', 'Sci-Fi']
# rating: 7.9
# directors: ['Doug Liman']
# stars: ['Tom Cruise', 'Emily Blunt', 'Bill Paxton']
# languages: ['English']
#
# id: tt14730032
# title: Phenomenon Blade Runner
# first_page_summary: In 1982 a film came to the cinema that is set in the near future of Los Angeles in 2019 and itself changed the future of cinema as it is one of the most influential science fiction films eve... Read all
# release_year: 2021
# mpaa:
# genres: ['Documentary']
# rating: 6.7
# directors: ['Boris Hars-Tschachotin']
# stars: ['Joanna Cassidy', 'Harrison Ford', 'Ryan Gosling']
# languages: ['German', 'English']
#
# id: tt5181838
# title: Back to the Future?
# first_page_summary: Marty and Doc Brown go back to 2015 and find that one detail has changed the future as they knew it.
# release_year: 2015
# mpaa:
# genres: ['Short', 'Sci-Fi']
# rating: 8.1
# directors: ['Kyle Chen']
# stars: ['Jeffrey Weissman', 'Logan Wildey', 'Michael Garcia']
# languages:
#
# id: tt0118884
# title: Contact
# first_page_summary: Dr. Ellie Arroway, after years of searching, finds conclusive radio proof of extraterrestrial intelligence, sending plans for a mysterious machine.
# release_year: 1997
# mpaa: PG
# genres: ['Drama', 'Mystery', 'Sci-Fi']
# rating: 7.5
# directors: ['Robert Zemeckis']
# stars: ['Jodie Foster', 'Matthew McConaughey', 'Tom Skerritt']
# languages: ['English', 'Spanish', 'German', 'Russian']
# ---------------------------
#
# <|user|>give me a science fiction movie similar to the movie Predestination(2014)
# <|assistant|>Sure! Based on your preference for science fiction movies like Predestination (2014), I would recommend the movie "Edge of Tomorrow" (2014). Both films share elements of sci-fi action and time travel themes. In Edge of Tomorrow, Tom Cruise plays the role of Major William Cage, who gets stuck in a time loop during a war against an alien race. As Cage tries to break free from this cycle, he realizes that the only way to win the war is by learning from his mistakes and working alongside the skilled Rita Vrataski (played by Emily Blunt). This film combines thrilling action sequences with thought-provoking ideas about fate and destiny, making it a must-watch for fans of Predestination.
# <|user|>give one that is directed by christopher nolan
# <|user|>
# Give me the search keywords derived from the conversation above.
# <|assistant|>
# Here are some potential search keywords for finding optimal movie recommendations based on your previous requests:
# - Science fiction movies
# - Time travel themes
# - Similar to Predestination (2014)
# - Christopher Nolan as director
#
# Some possible keyword combinations could include:
# - "science fiction time travel movies"
# - "movies like Predestination"
# - "Christopher Nolan sci-fi movies"
#
# These keywords can be used to narrow down search results on streaming platforms or online databases to find the best fit for your preferences.
#
#
# <|system|>You are a movie recommendation assistant. Your task is to recommend the best movie from the provided list based on the user's preferences and query. Ensure to select the movie that closely matches the user's request.
# The user is asking for a movie recommendation, and you have a list of movies to choose from.
# Based on the user's query and the given movie list, provide a detailed recommendation including the movie's title, release year, genres, rating, directors, stars, and a brief summary.
#
# Movie list:
# ---------------------------
# id: tt1631867
# title: Edge of Tomorrow
# first_page_summary: A soldier fighting aliens gets to relive the same day over and over again, the day restarting every time he dies.
# release_year: 2014
# mpaa: PG-13
# genres: ['Action', 'Adventure', 'Sci-Fi']
# rating: 7.9
# directors: ['Doug Liman']
# stars: ['Tom Cruise', 'Emily Blunt', 'Bill Paxton']
# languages: ['English']
#
# id: tt1877832
# title: X-Men: Days of Future Past
# first_page_summary: The X-Men send Wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.
# release_year: 2014
# mpaa: PG-13
# genres: ['Action', 'Adventure', 'Sci-Fi']
# rating: 7.9
# directors: ['Bryan Singer']
# stars: ['Patrick Stewart', 'Ian McKellen', 'Hugh Jackman']
# languages: ['English', 'Vietnamese', 'French']
#
# id: tt9759714
# title: Blade Runner(s)
# first_page_summary:
# release_year: 2019
# mpaa:
# genres: ['Short', 'Sci-Fi']
# rating: 5.9
# directors: ['Chris R. Notarile']
# stars: ['Harley Castro', 'Brian C. Chenworth', 'Edward Kasper']
# languages: ['English']
#
# id: tt0083658
# title: Blade Runner
# first_page_summary: A blade runner must pursue and terminate four replicants who stole a ship in space and have returned to Earth to find their creator.
# release_year: 1982
# mpaa: R
# genres: ['Action', 'Drama', 'Sci-Fi']
# rating: 8.1
# directors: ['Ridley Scott']
# stars: ['Harrison Ford', 'Rutger Hauer', 'Sean Young']
# languages: ['English', 'German', 'Cantonese', 'Japanese', 'Hungarian', 'Arabic', 'Korean']
#
# id: tt12139214
# title: Blade Runner 2089
# first_page_summary:
# release_year:
# mpaa:
# genres: ['Action', 'Sci-Fi']
# rating:
# directors:
# stars:
# languages:
# ---------------------------
#
# <|user|>give me a science fiction movie similar to the movie Predestination(2014)
# <|assistant|><|system|>You are a movie recommendation assistant. Your task is to recommend the best movie from the provided list based on the user's preferences and query. Ensure to select the movie that closely matches the user's request.
# The user is asking for a movie recommendation, and you have a list of movies to choose from.
# Based on the user's query and the given movie list, provide a detailed recommendation including the movie's title, release year, genres, rating, directors, stars, and a brief summary.
#
# Movie list:
# ---------------------------
# id: tt1877832
# title: X-Men: Days of Future Past
# first_page_summary: The X-Men send Wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.
# release_year: 2014
# mpaa: PG-13
# genres: ['Action', 'Adventure', 'Sci-Fi']
# rating: 7.9
# directors: ['Bryan Singer']
# stars: ['Patrick Stewart', 'Ian McKellen', 'Hugh Jackman']
# languages: ['English', 'Vietnamese', 'French']
#
# id: tt1631867
# title: Edge of Tomorrow
# first_page_summary: A soldier fighting aliens gets to relive the same day over and over again, the day restarting every time he dies.
# release_year: 2014
# mpaa: PG-13
# genres: ['Action', 'Adventure', 'Sci-Fi']
# rating: 7.9
# directors: ['Doug Liman']
# stars: ['Tom Cruise', 'Emily Blunt', 'Bill Paxton']
# languages: ['English']
#
# id: tt14730032
# title: Phenomenon Blade Runner
# first_page_summary: In 1982 a film came to the cinema that is set in the near future of Los Angeles in 2019 and itself changed the future of cinema as it is one of the most influential science fiction films eve... Read all
# release_year: 2021
# mpaa:
# genres: ['Documentary']
# rating: 6.7
# directors: ['Boris Hars-Tschachotin']
# stars: ['Joanna Cassidy', 'Harrison Ford', 'Ryan Gosling']
# languages: ['German', 'English']
#
# id: tt5181838
# title: Back to the Future?
# first_page_summary: Marty and Doc Brown go back to 2015 and find that one detail has changed the future as they knew it.
# release_year: 2015
# mpaa:
# genres: ['Short', 'Sci-Fi']
# rating: 8.1
# directors: ['Kyle Chen']
# stars: ['Jeffrey Weissman', 'Logan Wildey', 'Michael Garcia']
# languages:
#
# id: tt0118884
# title: Contact
# first_page_summary: Dr. Ellie Arroway, after years of searching, finds conclusive radio proof of extraterrestrial intelligence, sending plans for a mysterious machine.
# release_year: 1997
# mpaa: PG
# genres: ['Drama', 'Mystery', 'Sci-Fi']
# rating: 7.5
# directors: ['Robert Zemeckis']
# stars: ['Jodie Foster', 'Matthew McConaughey', 'Tom Skerritt']
# languages: ['English', 'Spanish', 'German', 'Russian']
# ---------------------------
#
# <|user|>give me a science fiction movie similar to the movie Predestination(2014)
# <|assistant|>Sure! Based on your preference for science fiction movies like Predestination (2014), I would recommend the movie "Edge of Tomorrow" (2014). Both films share elements of sci-fi action and time travel themes. In Edge of Tomorrow, Tom Cruise plays the role of Major William Cage, who gets stuck in a time loop during a war against an alien race. As Cage tries to break free from this cycle, he realizes that the only way to win the war is by learning from his mistakes and working alongside the skilled Rita Vrataski (played by Emily Blunt). This film combines thrilling action sequences with thought-provoking ideas about fate and destiny, making it a must-watch for fans of Predestination.
# <|user|>give one that is directed by christopher nolan
# <|assistant|>Absolutely! If you enjoyed Christopher Nolan's directing style in Predestination (which was actually written and directed by the Spierigs Brothers), then I highly recommend watching Christopher Nolan's Inception (2010). It also falls under the science fiction genre and follows Leonardo DiCaprio's character, Dominick Cobb, as he leads a team to implant an idea into someone else's subconscious through dream sharing technology. Inception explores themes such as perception, reality, and consciousness, which are hallmarks of Nolan's storytelling technique. With its intricate plot twists and mind-bending visuals, Inception is sure to leave you fascinated and engaged throughout.
