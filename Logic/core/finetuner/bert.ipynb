# %%
# https://drive.google.com/file/d/1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI/view?usp=sharing
# download using gdown
# !gdown --id 1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI
import os
os.environ['WANDB_MODE'] = 'disabled'

# %%
from Logic.core.finetuner.BertFinetuner_mask import BERTFinetuner

# %% [markdown]
# # Instantiate the class

# %%
bert_finetuner = BERTFinetuner('training_data/IMDB_crawled.json', top_n_genres=5)

# %% [markdown]
# # Load & Preprocess Dataset

# %%
bert_finetuner.load_dataset()
bert_finetuner.preprocess_genre_distribution()
bert_finetuner.split_dataset(0.1, 0.1)

# %% [markdown]
# # Fine-tune BERT model

# %%
bert_finetuner.fine_tune_bert(batch_size=4, warmup_steps=1000)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
#   0%|          | 0/8305 [00:00<?, ?it/s]
# {'loss': 0.6697, 'grad_norm': 2.4545769691467285, 'learning_rate': 5.000000000000001e-07, 'epoch': 0.01}
# {'loss': 0.6702, 'grad_norm': 2.6539714336395264, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.01}
# ...

# %% [markdown]
# # Compute metrics

# %%
bert_finetuner.evaluate_model()
# Out:
#   0%|          | 0/104 [00:00<?, ?it/s]
# {'accuracy': 0.3935018050541516, 'f1': 0.7094342753893567, 'precision': 0.7050473440220008, 'recall': 0.7167673716012085}

# %% [markdown]
# # Save the model (optional)

# %%
bert_finetuner.save_model('Movie_Genre_Classifier_v2')
